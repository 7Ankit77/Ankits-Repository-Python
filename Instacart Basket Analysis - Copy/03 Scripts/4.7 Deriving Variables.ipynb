# %% [markdown]
# # Content List

# %% [markdown]
# 1. Importing Libraries
# 2. Importing Dataset
# 3. Slicing the Data
# 4. Creating a Price Label Column using Functions
# 5. Grouping Price Ranges and Creating a New Column
# 6. Creating a Column for Busiest Day
# 7. Creating a Column for Busiest Period of Day
# 8. Exporting Data with Pickle

# %% [markdown]
# ## 1. Importing Libraries

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2. Importing Dataset

# %%
#Importing Dataset
ords_prods_merge = pd.read_pickle(r'C:\Users\Ankit\Documents\CareerFoundry\Achievement 4\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged.pkl')

# %% [markdown]
# ## 3. Slicing the Data

# %%
df = ords_prods_merge[:1000000]

# %%
df
# Out:
#         product_id                product_name  aisle_id  department_id  \
# 0                1  Chocolate Sandwich Cookies        61             19
# 1                1  Chocolate Sandwich Cookies        61             19
# 2                1  Chocolate Sandwich Cookies        61             19
# 3                1  Chocolate Sandwich Cookies        61             19
# 4                1  Chocolate Sandwich Cookies        61             19
# ...            ...                         ...       ...            ...
# 999995        2078  Unsalted Pure Irish Butter        36             16
# 999996        2078  Unsalted Pure Irish Butter        36             16
# 999997        2078  Unsalted Pure Irish Butter        36             16
# 999998        2078  Unsalted Pure Irish Butter        36             16
# 999999        2078  Unsalted Pure Irish Butter        36             16
#
#         prices  order_id  user_id eval_set  order_number  order_dow  \
# ...

# %% [markdown]
# ## 4. Creating a Price Label Column using Functions

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Ankit\AppData\Local\Temp\ipykernel_14408\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  hour_of_day  \
# 0   3139998      138    prior            28          6           11
# 1   1977647      138    prior            30          6           17
# 2    389851      709    prior             2          0           21
# 3    652770      764    prior             1          3           13
# 4   1813452      764    prior             3          4           17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# ...

# %% [markdown]
# ## 5. Grouping Price Ranges and Creating a New Column

# %%
df['price_range'].value_counts()
# Out:
# Mid-range product    652638
# Low-range product    338018
# High range             9344
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 24.5

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Ankit\AppData\Local\Temp\ipykernel_14408\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  hour_of_day  \
# 0   3139998      138    prior            28          6           11
# 1   1977647      138    prior            30          6           17
# 2    389851      709    prior             2          0           21
# 3    652770      764    prior             1          3           13
# 4   1813452      764    prior             3          4           17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# ...

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     652638
# Low-range product     338018
# High-range product      9344
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ## 7. Creating a Column for Busiest Period of Day

# %%
#Creating a List using if-then to add as a column
result = []

for value in ords_prods_merge["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  hour_of_day  \
# 0   3139998      138    prior            28          6           11
# 1   1977647      138    prior            30          6           17
# 2    389851      709    prior             2          0           21
# 3    652770      764    prior             1          3           13
# 4   1813452      764    prior             3          4           17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge     busiest_day
# ...

# %%
ords_prods_merge['busiest_day'].value_counts()
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %%
#Creating a List using if-then to add as a column
results = []

for value in ords_prods_merge["order_dow"]:
  if value == 0:
    results.append("Busiest days")
  elif value == 1:
    results.append("Busiest days")
  elif value == 3:
    results.append("Least busy days")
  elif value == 4:
    results.append("Least busy days")
  else:
    results.append("Regularly busy")

# %%
ords_prods_merge['order_dow'].value_counts()
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_dow, dtype: int64

# %%
ords_prods_merge['busiest_days'] = results

# %%
results
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Least busy days',
#  'Least busy days',
#  'Busiest days',
#  'Regularly busy',
#  'Least busy days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Least busy days',
#  'Least busy days',
#  'Regularly busy',
#  'Least busy days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Least busy days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Least busy days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Least busy days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
# ...

# %%
#Checking values for accuracy
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  hour_of_day  \
# 0   3139998      138    prior            28          6           11
# 1   1977647      138    prior            30          6           17
# 2    389851      709    prior             2          0           21
# 3    652770      764    prior             1          3           13
# 4   1813452      764    prior             3          4           17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# ...

# %%
#Checking values for accuracy
ords_prods_merge['busiest_days'].value_counts()
# Out:
# Regularly busy     12916111
# Busiest days       11864412
# Least busy days     7624336
# Name: busiest_days, dtype: int64

# %% [markdown]
# #2. the values look like they all add up to an appropriate amount of rows and that most of the days are (over 2/3) are busy days

# %%
ords_prods_merge['busiest_days'].describe()
# Out:
# count           32404859
# unique                 3
# top       Regularly busy
# freq            12916111
# Name: busiest_days, dtype: object

# %%
result2 = []

for value in ords_prods_merge["hour_of_day"]:
  if value == 10:
    result2.append("Most orders")
  elif value == 3:
    result2.append("Fewest orders")
  else:
    result2.append("Average orders")

# %%
ords_prods_merge['hour_of_day'].value_counts()
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: hour_of_day, dtype: int64

# %%
ords_prods_merge['busiest_period_of_day'] = result2

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  hour_of_day  \
# 0   3139998      138    prior            28          6           11
# 1   1977647      138    prior            30          6           17
# 2    389851      709    prior             2          0           21
# 3    652770      764    prior             1          3           13
# 4   1813452      764    prior             3          4           17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# ...

# %%
#Frequency of new column
ords_prods_merge['busiest_period_of_day'].value_counts()
# Out:
# Average orders    29591818
# Most orders        2761760
# Fewest orders        51281
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# ## 8. Exporting Data with Pickle

# %%
path = r'C:\Users\Ankit\Documents\CareerFoundry\Achievement 4\Instacart Basket Analysis'

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
